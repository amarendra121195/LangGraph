# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()

llm = ChatOpenAI()

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"',
#  'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"', 'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-b070-68ff-8002-2395f88cdadb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-24T16:41:25.854438+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"', 'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-b070-68ff-8002-2395f88cdadb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-24T16:41:25.854438+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-24T16:41:24.240912+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, tasks=(PregelTask(id='dc446a0e-d5cf-3d97-5133-829db797e644', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-24T16:41:23.352576+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, tasks=(PregelTask(id='890195d2-40de-6db6-0a7c-91faf4ce5b36', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-24T16:41:23.351477+00:00', parent_config=None, tasks=(PregelTask(id='8196588a-7264-6cb1-4061-abffb1890026', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta go to the party? Because it heard it was going to be a saucy affair!',
#  'explanation': 'This joke plays on the double meaning of the word "saucy." In one sense, "saucy" can mean lively, spicy, or exciting, which is often how people describe a fun party. In another sense, "saucy" can also refer to being covered with sauce, which is a common topping for pasta dishes. So, the joke is that the pasta went to the party because it thought it was going to be a lively and exciting event, but also because it was expecting there to be a lot of sauce, which is a common accompaniment to pasta.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"', 'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-b070-68ff-8002-2395f88cdadb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-24T16:41:25.854438+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"', 'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-b070-68ff-8002-2395f88cdadb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-24T16:41:25.854438+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-24T16:41:24.240912+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, tasks=(PregelTask(id='dc446a0e-d5cf-3d97-5133-829db797e644', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-24T16:41:23.352576+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, tasks=(PregelTask(id='890195d2-40de-6db6-0a7c-91faf4ce5b36', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-24T16:41:23.351477+00:00', parent_config=None, tasks=(PregelTask(id='8196588a-7264-6cb1-4061-abffb1890026', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5"}})

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"', 'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-b070-68ff-8002-2395f88cdadb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-24T16:41:25.854438+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-24T16:41:24.240912+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, tasks=(PregelTask(id='dc446a0e-d5cf-3d97-5133-829db797e644', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-24T16:41:23.352576+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, tasks=(PregelTask(id='890195d2-40de-6db6-0a7c-91faf4ce5b36', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-24T16:41:23.351477+00:00', parent_config=None, tasks=(PregelTask(id='8196588a-7264-6cb1-4061-abffb1890026', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0c9549-5288-6842-8000-81c45b68a210'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9549-5288-6842-8000-81c45b68a210'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2025-11-24T16:42:36.538272+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='e5391cb1-3dce-7eac-bd43-a6b9f437844b', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"', 'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-b070-68ff-8002-2395f88cdadb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-24T16:41:25.854438+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-24T16:41:24.240912+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, tasks=(PregelTask(id='dc446a0e-d5cf-3d97-5133-829db797e644', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-24T16:41:23.352576+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, tasks=(PregelTask(id='890195d2-40de-6db6-0a7c-91faf4ce5b36', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-24T16:41:23.351477+00:00', parent_config=None, tasks=(PregelTask(id='8196588a-7264-6cb1-4061-abffb1890026', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc72-ca16-6359-8001-7eea05e07dd2"}})
# Out:
# ---------------------------------------------------------------------------
# EmptyInputError                           Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc72-ca16-6359-8001-7eea05e07dd2"}})
#
# File c:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\langgraph\pregel\main.py:3050, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3047 chunks: list[dict[str, Any] | Any] = []
#    3048 interrupts: list[Interrupt] = []
# -> 3050 for chunk in self.stream(
#    3051     input,
#    3052     config,
#    3053     context=context,
#    3054     stream_mode=["updates", "values"]
#    3055     if stream_mode == "values"
#    3056     else stream_mode,
#    3057     print_mode=print_mode,
#    3058     output_keys=output_keys,
#    3059     interrupt_before=interrupt_before,
#    3060     interrupt_after=interrupt_after,
#    3061     durability=durability,
#    3062     **kwargs,
#    3063 ):
#    3064     if stream_mode == "values":
#    3065         if len(chunk) == 2:
#
# File c:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\langgraph\pregel\main.py:2569, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2566 runtime = parent_runtime.merge(runtime)
#    2567 config[CONF][CONFIG_KEY_RUNTIME] = runtime
# -> 2569 with SyncPregelLoop(
#    2570     input,
#    2571     stream=StreamProtocol(stream.put, stream_modes),
#    2572     config=config,
#    2573     store=store,
#    2574     cache=cache,
#    2575     checkpointer=checkpointer,
#    2576     nodes=self.nodes,
#    2577     specs=self.channels,
#    2578     output_keys=output_keys,
#    2579     input_keys=self.input_channels,
#    2580     stream_keys=self.stream_channels_asis,
#    2581     interrupt_before=interrupt_before_,
#    2582     interrupt_after=interrupt_after_,
#    2583     manager=run_manager,
#    2584     durability=durability_,
#    2585     trigger_to_nodes=self.trigger_to_nodes,
#    2586     migrate_checkpoint=self._migrate_checkpoint,
#    2587     retry_policy=self.retry_policy,
#    2588     cache_policy=self.cache_policy,
#    2589 ) as loop:
#    2590     # create runner
#    2591     runner = PregelRunner(
#    2592         submit=config[CONF].get(
#    2593             CONFIG_KEY_RUNNER_SUBMIT, weakref.WeakMethod(loop.submit)
#    (...)   2596         node_finished=config[CONF].get(CONFIG_KEY_NODE_FINISHED),
#    2597     )
#    2598     # enable subgraph streaming
#
# File c:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\langgraph\pregel\_loop.py:1114, in SyncPregelLoop.__enter__(self)
#    1112 self.stop = self.step + self.config["recursion_limit"] + 1
#    1113 self.checkpoint_previous_versions = self.checkpoint["channel_versions"].copy()
# -> 1114 self.updated_channels = self._first(
#    1115     input_keys=self.input_keys,
#    1116     updated_channels=set(self.checkpoint.get("updated_channels"))  # type: ignore[arg-type]
#    1117     if self.checkpoint.get("updated_channels")
#    1118     else None,
#    1119 )
#    1121 return self
#
# File c:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\langgraph\pregel\_loop.py:725, in PregelLoop._first(self, input_keys, updated_channels)
#     723     self._put_checkpoint({"source": "input"})
#     724 elif CONFIG_KEY_RESUMING not in configurable:
# --> 725     raise EmptyInputError(f"Received no input for {input_keys}")
#     726 # update config
#     727 if not self.is_nested:
#
# EmptyInputError: Received no input for __start__

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9549-5288-6842-8000-81c45b68a210'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2025-11-24T16:42:36.538272+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='e5391cb1-3dce-7eac-bd43-a6b9f437844b', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"', 'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-b070-68ff-8002-2395f88cdadb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-11-24T16:41:25.854438+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-a10d-64a1-8001-b5cfbb99819a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-24T16:41:24.240912+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, tasks=(PregelTask(id='dc446a0e-d5cf-3d97-5133-829db797e644', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on the phrase "see you later" and the word "cheese." The slice of pizza is using a pun to humorously bid farewell to the delivery driver. By replacing "see" with "cheese," the joke is giving a lighthearted and cheesy twist to the typical goodbye phrase. It relies on the double meaning of "cheese" as both a common pizza topping and a way to say goodbye.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9894-6807-8000-3a243d2dbd86'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-11-24T16:41:23.352576+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, tasks=(PregelTask(id='890195d2-40de-6db6-0a7c-91faf4ce5b36', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'What did the slice of pizza say to the delivery driver? "Cheese you later!"'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0c9546-9891-6d1b-bfff-4f23a53f61c3'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-11-24T16:41:23.351477+00:00', parent_config=None, tasks=(PregelTask(id='8196588a-7264-6cb1-4061-abffb1890026', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# Fault Tolerance

# %% [markdown]
# from langgraph.graph import StateGraph, END
# from langgraph.checkpoint.memory import InMemorySaver
# from typing import TypedDict
# import time

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(1000)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
